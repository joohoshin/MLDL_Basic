# %% [markdown]
# <a href="https://colab.research.google.com/github/joohoshin/MLDL_Basic/blob/master/22_1_Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# L1, L2 Regularization을 통해 Overfitting을 줄일 수 있습니다
#
# 교재 4.5장 참고

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %%
# fashion mnist로 비교해봅시다

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
print(x_train.shape, y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28) (60000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']     

epochs = 20

# %%
num_classes = 10

y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

x_train = np.expand_dims(x_train, axis=3)
x_test = np.expand_dims(x_test, axis=3)

x_train = x_train/255
x_test = x_test/255

from tensorflow.keras import layers, models

model = models.Sequential()
model.add(layers.Conv2D(32,(5,5), padding='valid', activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPool2D(2,2))
model.add(layers.Conv2D(64,(5,5), padding='valid', activation='relu'))
model.add(layers.MaxPool2D(2,2))
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

history = model.fit(x_train, y_train, batch_size=32, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 1,111,946
# Trainable params: 1,111,946
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4529 - acc: 0.8346 - val_loss: 0.3609 - val_acc: 0.8705
# Epoch 2/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3075 - acc: 0.8879 - val_loss: 0.3061 - val_acc: 0.8901
# Epoch 3/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2664 - acc: 0.9025 - val_loss: 0.2747 - val_acc: 0.8981
# Epoch 4/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2375 - acc: 0.9124 - val_loss: 0.2796 - val_acc: 0.8996
# Epoch 5/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2136 - acc: 0.9215 - val_loss: 0.2515 - val_acc: 0.9129
# Epoch 6/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1967 - acc: 0.9271 - val_loss: 0.2595 - val_acc: 0.9077
# Epoch 7/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1770 - acc: 0.9338 - val_loss: 0.2611 - val_acc: 0.9091
# Epoch 8/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1651 - acc: 0.9380 - val_loss: 0.2824 - val_acc: 0.9043
# Epoch 9/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1527 - acc: 0.9421 - val_loss: 0.2767 - val_acc: 0.9104
# Epoch 10/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1396 - acc: 0.9466 - val_loss: 0.3061 - val_acc: 0.9060
# Epoch 11/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1326 - acc: 0.9499 - val_loss: 0.3040 - val_acc: 0.9111
# Epoch 12/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1215 - acc: 0.9543 - val_loss: 0.3249 - val_acc: 0.9075
# Epoch 13/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1132 - acc: 0.9578 - val_loss: 0.3162 - val_acc: 0.9122
# Epoch 14/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1050 - acc: 0.9600 - val_loss: 0.3406 - val_acc: 0.9126
# Epoch 15/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0975 - acc: 0.9629 - val_loss: 0.3665 - val_acc: 0.9132
# Epoch 16/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0981 - acc: 0.9632 - val_loss: 0.3501 - val_acc: 0.9115
# Epoch 17/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0906 - acc: 0.9657 - val_loss: 0.3984 - val_acc: 0.9087
# Epoch 18/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0867 - acc: 0.9684 - val_loss: 0.4070 - val_acc: 0.9112
# Epoch 19/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0820 - acc: 0.9698 - val_loss: 0.4596 - val_acc: 0.9068
# Epoch 20/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0756 - acc: 0.9715 - val_loss: 0.4756 - val_acc: 0.9110

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train', 'test'], loc='upper left')

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(32,(5,5), padding='valid', activation='relu', input_shape=(28,28,1)))
model2.add(layers.MaxPool2D(2,2))
model2.add(layers.Conv2D(64,(5,5), padding='valid', activation='relu'))
model2.add(layers.MaxPool2D(2,2))
model2.add(layers.Flatten())
model2.add(layers.Dense(1024, activation='relu'))
model2.add(layers.Dense(512, activation='relu'))
model2.add(layers.Dense(10, activation='softmax'))
model2.summary()

model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

history2 = model2.fit(x_train, y_train, batch_size=32,
          epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,631,626
# Trainable params: 1,631,626
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4374 - acc: 0.8379 - val_loss: 0.3322 - val_acc: 0.8781
# Epoch 2/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2878 - acc: 0.8939 - val_loss: 0.2956 - val_acc: 0.8928
# Epoch 3/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2431 - acc: 0.9100 - val_loss: 0.2919 - val_acc: 0.8986
# Epoch 4/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2131 - acc: 0.9195 - val_loss: 0.2721 - val_acc: 0.9050
# Epoch 5/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1878 - acc: 0.9291 - val_loss: 0.2721 - val_acc: 0.9063
# Epoch 6/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1635 - acc: 0.9371 - val_loss: 0.3030 - val_acc: 0.9074
# Epoch 7/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1452 - acc: 0.9438 - val_loss: 0.3251 - val_acc: 0.9016
# Epoch 8/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1302 - acc: 0.9501 - val_loss: 0.3260 - val_acc: 0.9030
# Epoch 9/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1134 - acc: 0.9567 - val_loss: 0.3376 - val_acc: 0.9121
# Epoch 10/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1038 - acc: 0.9600 - val_loss: 0.3421 - val_acc: 0.9144
# Epoch 11/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0933 - acc: 0.9638 - val_loss: 0.3579 - val_acc: 0.9093
# Epoch 12/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0823 - acc: 0.9684 - val_loss: 0.4206 - val_acc: 0.9076
# Epoch 13/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0776 - acc: 0.9708 - val_loss: 0.4213 - val_acc: 0.9131
# Epoch 14/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0747 - acc: 0.9724 - val_loss: 0.4495 - val_acc: 0.9111
# Epoch 15/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0649 - acc: 0.9759 - val_loss: 0.4613 - val_acc: 0.9123
# Epoch 16/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0602 - acc: 0.9782 - val_loss: 0.5414 - val_acc: 0.9121
# Epoch 17/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0557 - acc: 0.9799 - val_loss: 0.5362 - val_acc: 0.9087
# Epoch 18/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0569 - acc: 0.9797 - val_loss: 0.5509 - val_acc: 0.9091
# Epoch 19/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0530 - acc: 0.9816 - val_loss: 0.5652 - val_acc: 0.9088
# Epoch 20/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0459 - acc: 0.9839 - val_loss: 0.6531 - val_acc: 0.9063

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.legend(['train', 'test','train2', 'test2'], loc='upper left')

# %%
model3 = models.Sequential()
model3.add(layers.Conv2D(32,(5,5), padding='valid', activation='relu', input_shape=(28,28,1)))
model3.add(layers.MaxPool2D(2,2))
model3.add(layers.Conv2D(64,(5,5), padding='valid', activation='relu'))
model3.add(layers.MaxPool2D(2,2))
model3.add(layers.Flatten())
model3.add(layers.Dense(1024,kernel_regularizer=keras.regularizers.l2(0.001), activation='relu'))
model3.add(layers.Dense(512,kernel_regularizer=keras.regularizers.l2(0.001), activation='relu'))
model3.add(layers.Dense(10, activation='softmax'))
model3.summary()

model3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

history3 = model3.fit(x_train, y_train, batch_size=32,
          epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,631,626
# Trainable params: 1,631,626
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6674 - acc: 0.8268 - val_loss: 0.4579 - val_acc: 0.8665
# Epoch 2/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4028 - acc: 0.8797 - val_loss: 0.3889 - val_acc: 0.8801
# Epoch 3/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3428 - acc: 0.8963 - val_loss: 0.3377 - val_acc: 0.8968
# Epoch 4/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3096 - acc: 0.9065 - val_loss: 0.3259 - val_acc: 0.8995
# Epoch 5/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2863 - acc: 0.9118 - val_loss: 0.3154 - val_acc: 0.9042
# Epoch 6/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2684 - acc: 0.9174 - val_loss: 0.2990 - val_acc: 0.9068
# Epoch 7/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2567 - acc: 0.9208 - val_loss: 0.3172 - val_acc: 0.9048
# Epoch 8/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2454 - acc: 0.9241 - val_loss: 0.2981 - val_acc: 0.9079
# Epoch 9/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2338 - acc: 0.9293 - val_loss: 0.3017 - val_acc: 0.9090
# Epoch 10/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2267 - acc: 0.9303 - val_loss: 0.3051 - val_acc: 0.9074
# Epoch 11/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2169 - acc: 0.9352 - val_loss: 0.3047 - val_acc: 0.9070
# Epoch 12/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2108 - acc: 0.9375 - val_loss: 0.3113 - val_acc: 0.9060
# Epoch 13/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2045 - acc: 0.9399 - val_loss: 0.3399 - val_acc: 0.8982
# Epoch 14/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1997 - acc: 0.9402 - val_loss: 0.3161 - val_acc: 0.9069
# Epoch 15/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1915 - acc: 0.9430 - val_loss: 0.3044 - val_acc: 0.9095
# Epoch 16/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1880 - acc: 0.9452 - val_loss: 0.3342 - val_acc: 0.9034
# Epoch 17/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1828 - acc: 0.9463 - val_loss: 0.3204 - val_acc: 0.9066
# Epoch 18/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1783 - acc: 0.9487 - val_loss: 0.3183 - val_acc: 0.9068
# Epoch 19/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1712 - acc: 0.9509 - val_loss: 0.3156 - val_acc: 0.9078
# Epoch 20/20
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1673 - acc: 0.9527 - val_loss: 0.3139 - val_acc: 0.9071

# %%
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.legend(['train', 'test'], loc='upper left')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.legend(['train1', 'test1','train3', 'test3'], loc='upper left')

# %%
plt.plot(history3.history['acc'])
plt.plot(history3.history['val_acc'])
plt.legend(['train', 'test'], loc='upper left')
